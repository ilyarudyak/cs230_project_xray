# %%
from data_prep import ChestXrayDataset
import utils

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## get datasets

# %%
ds = ChestXrayDataset()

# %%
train_ds, val_ds = ds.build_datasets()

# %%
image_batch, label_batch = next(iter(train_ds))

# %%
utils.show_batch(image_batch, label_batch, ds)

# %%
image_batch, label_batch = next(iter(val_ds))

# %%
utils.show_batch(image_batch, label_batch, ds)
